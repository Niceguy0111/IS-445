# %%
import numpy as npy
 
# creating a 2-d array
arr1 = npy.array([[1, 3, 5, 7], [2, 4, 6, 8]])
 
# creating a 3-d array
arr2 = npy.array([[[1, 2], [3, 4]], [[5, 6], [7, 8]]])
 
# printing the shape of arrays
# first element of tuple gives
# dimension of arrays second
# element of tuple gives number
# of element of each dimension
print(arr1.shape)
# Out:
# (2, 4)

# %%
from matplotlib import pyplot as plt
plt.imshow(data, interpolation='nearest')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31164\4038998027.py in <module>
#       1 from matplotlib import pyplot as plt
# ----> 2 plt.imshow(data, interpolation='nearest')
#       3 plt.show()
#
# NameError: name 'data' is not defined

# %%
import numpy as np
data = np.zeros( (512,512,3), dtype=np.uint8)
data[256,256] = [255,0,0]

from matplotlib import pyplot as plt
plt.imshow(data, interpolation='nearest')
plt.show()

# %%
from PIL import Image
import numpy as np

w, h = 512, 512
data = np.zeros((h, w, 3), dtype=np.uint8)
data[0:256, 0:256] = [255, 0, 0] # red patch in upper left
img = Image.fromarray(data, 'RGB')
img.show()

# %%
import numpy as np
data = np.zeros( (512,512,3), dtype=np.uint8)
data[[256,256] = [255,0,0],
     [200,200] = [255,0,0]]

from matplotlib import pyplot as plt
plt.imshow(data, interpolation='nearest')
plt.show()
# Out:
#   File "C:\Users\HPC500C602\AppData\Local\Temp\ipykernel_31164\1244956479.py", line 3
#     data[[256,256] = [255,0,0],
#                    ^
# SyntaxError: invalid syntax

# %%
import numpy as np
import matplotlib.pyplot as plt
# Creating a numpy array
X = np.array([1,2,3,4,5])
Y = np.array([1,2,3,4,5])
# Plotting point using scatter method
plt.scatter(X,Y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# Creating a numpy array
X = np.array([1,2,3,-1,-2])
Y = np.array([6,1,-4,2,5])
# Plotting point using scatter method
plt.scatter(X,Y)
plt.show()

# %%
import matplotlib.pyplot as plt
x1, y1 = [0, 6], [1, 2]
x2, y2 = [6, 10], [2, 1]
x3, y3 = [0,10],[1,1]
plt.plot(x1, y1, x2, y2, x3, y3, marker = '+', color="black")
plt.show()

# %%
import matplotlib.pyplot as plt

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'Path 1', 'Path 2', 'Path 3'
sizes = [10, 60, 30]


fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()
