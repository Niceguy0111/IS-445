# %%
import pandas as pd
import ipywidgets

# %%
dfUfo = pd.read_csv('ufo-scrubbed-geocoded-time-standardized-00.csv', names=['Sighting date', 'City', 'State', 'Country', 'Type', 'Seconds', 'Time', 'Description', 'Reported Date', 'Lat', 'Long'])
dfUfo
# Out:
#           Sighting date                  City State Country      Type  \
# 0      10/10/1949 20:30            san marcos    tx      us  cylinder
# 1      10/10/1949 21:00          lackland afb    tx     NaN     light
# 2      10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3      10/10/1956 21:00                  edna    tx      us    circle
# 4      10/10/1960 20:00               kaneohe    hi      us     light
# ...                 ...                   ...   ...     ...       ...
# 80327    9/9/2013 21:15             nashville    tn      us     light
# 80328    9/9/2013 22:00                 boise    id      us    circle
# 80329    9/9/2013 22:00                  napa    ca      us     other
# 80330    9/9/2013 22:20                vienna    va      us    circle
# 80331    9/9/2013 23:00                edmond    ok      us     cigar
#
#        Seconds        Time                                        Description  \
# ...

# %%
demoPlot = dfUfo.plot.scatter(x='Long', y='Lat')

# %%
dfUsa = dfUfo[ dfUfo[ 'Country' ] == 'us' ]
dfUsa
# Out:
#           Sighting date        City State Country      Type  Seconds  \
# 0      10/10/1949 20:30  san marcos    tx      us  cylinder   2700.0
# 3      10/10/1956 21:00        edna    tx      us    circle     20.0
# 4      10/10/1960 20:00     kaneohe    hi      us     light    900.0
# 5      10/10/1961 19:00     bristol    tn      us    sphere    300.0
# 7      10/10/1965 23:45     norwalk    ct      us      disk   1200.0
# ...                 ...         ...   ...     ...       ...      ...
# 80327    9/9/2013 21:15   nashville    tn      us     light    600.0
# 80328    9/9/2013 22:00       boise    id      us    circle   1200.0
# 80329    9/9/2013 22:00        napa    ca      us     other   1200.0
# 80330    9/9/2013 22:20      vienna    va      us    circle      5.0
# 80331    9/9/2013 23:00      edmond    ok      us     cigar   1020.0
#
#              Time                                        Description  \
# ...

# %%
demoPlot2 = dfUsa.plot.scatter(x='Long', y='Lat')

# %%
countryFilter = ipywidgets.Textarea()
countryFilter
# Out:
# Textarea(value='')

# %%
dfCountry = dfUfo[ dfUfo[ 'Country' ] == countryFilter.value ]
dfCountry
# Out:
#           Sighting date                                               City  \
# 103    10/10/2001 04:33                         sydney (nsw&#44 australia)
# 112    10/10/2002 04:00         adelaide (pt. wakefield) (south australia)
# 285    10/11/1986 20:30                  alice springs  (nt&#44 australia)
# 855     10/1/2007 02:00                        adelaide  (south australia)
# 990    10/12/1975 01:00  perth (w. of; southern cross) (western australia)
# ...                 ...                                                ...
# 78650   9/30/2001 23:35                     wollongong (nsw&#44 australia)
# 79234    9/4/2012 02:30                                  perth (australia)
# 79674    9/7/1983 19:30                                 sydney (australia)
# 79791    9/7/2008 19:32                               brisbane (australia)
# 80217    9/9/2007 19:01                              melbourne (australia)
#
#       State Country       Type  Seconds        Time  \
# ...

# %%
demoPlot3 = dfCountry.plot.scatter(x='Long', y='Lat')

# %%
dfUsa.State.unique()
# Out:
# array(['tx', 'hi', 'tn', 'ct', 'al', 'fl', 'ca', 'nc', 'ny', 'ky', 'mi',
#        'ma', 'ks', 'sc', 'wa', 'co', 'nh', 'wi', 'me', 'ga', 'pa', 'il',
#        'ar', 'mo', 'oh', 'in', 'az', 'mn', 'nv', 'ne', 'or', 'ia', 'va',
#        'id', 'nm', 'nj', 'wv', 'ok', 'ri', 'vt', 'la', 'pr', 'ak', 'ms',
#        'ut', 'md', 'mt', 'wy', 'sd', 'de', 'nd', 'dc'], dtype=object)

# %%
stateFilter = ipywidgets.Dropdown(
    options = [ 'tx', 'hi', 'tn', 'ct', 'al', 'fl', 'ca', 'nc', 'ny', 'ky', 'mi',
       'ma', 'ks', 'sc', 'wa', 'co', 'nh', 'wi', 'me', 'ga', 'pa', 'il',
       'ar', 'mo', 'oh', 'in', 'az', 'mn', 'nv', 'ne', 'or', 'ia', 'va',
       'id', 'nm', 'nj', 'wv', 'ok', 'ri', 'vt', 'la', 'pr', 'ak', 'ms',
       'ut', 'md', 'mt', 'wy', 'sd', 'de', 'nd', 'dc' ]
)

# %%
stateFilter
# Out:
# Dropdown(options=('tx', 'hi', 'tn', 'ct', 'al', 'fl', 'ca', 'nc', 'ny', 'ky', 'mi', 'ma', 'ks', 'sc', 'wa', 'c…

# %%
import datetime as dt

dfUsState = dfUsa[ dfUsa.State == stateFilter.value ]
dfUsState[ 'Sighting date' ] = pd.to_datetime(dfUsState[ 'Sighting date' ])
dfUsState[ 'Sighting date' ].dt.year.plot.hist( title = stateFilter.value + ' Sightings per Year', xlabel = 'Sighting Year', bins = 50 )
# Out:
# C:\Users\dyan0\AppData\Local\Temp\ipykernel_134916\134015021.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfUsState[ 'Sighting date' ] = pd.to_datetime(dfUsState[ 'Sighting date' ])
# <Axes: title={'center': 'hi Sightings per Year'}, xlabel='Sighting Year', ylabel='Frequency'>
